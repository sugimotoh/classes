# %% [markdown]
# <a href="https://colab.research.google.com/github/sugimotoh/classes/blob/main/marketingmodels2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###***Part1***###
# **code 1-1: Pip Installs Python**

# %%
pip install ucimlrepo

# %% [markdown]
# code 1-2: scraping data by using ucimlreop

# %%
from ucimlrepo import fetch_ucirepo
# fetch dataset
bank_marketing = fetch_ucirepo(id=222)

# data (as pandas dataframes)
X = bank_marketing.data.features
y = bank_marketing.data.targets

# metadata
#print(bank_marketing.metadata)
# variable information
#print(bank_marketing.variables)

# %% [markdown]
# code 1-3: check the data X and X head

# %%
X
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married        NaN      no     1506     yes   no
# 4       33           NaN    single        NaN      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
X.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married        NaN      no     1506     yes   no
# 4   33           NaN   single        NaN      no        1      no   no
#
#   contact  day_of_week month  duration  campaign  pdays  previous poutcome
# 0     NaN            5   may       261         1     -1         0      NaN
# 1     NaN            5   may       151         1     -1         0      NaN
# 2     NaN            5   may        76         1     -1         0      NaN
# 3     NaN            5   may        92         1     -1         0      NaN
# 4     NaN            5   may       198         1     -1         0      NaN

# %% [markdown]
# code 1-4: check the vector y and y head

# %%
y
# Out:
#          y
# 0       no
# 1       no
# 2       no
# 3       no
# 4       no
# ...    ...
# 45206  yes
# 45207  yes
# 45208  yes
# 45209   no
# 45210   no
#
# [45211 rows x 1 columns]

# %% [markdown]
# ###**Part2**###
# code 2-1: sample size, the number of records

# %%
y.size
# Out:
# 45211

# %% [markdown]
# code 2-2: 10th to 30th of vector y

# %%
y[9:32]
# Out:
#      y
# 9   no
# 10  no
# 11  no
# 12  no
# 13  no
# 14  no
# 15  no
# 16  no
# 17  no
# 18  no
# 19  no
# 20  no
# 21  no
# 22  no
# 23  no
# 24  no
# 25  no
# 26  no
# 27  no
# 28  no
# 29  no
# 30  no
# 31  no

# %% [markdown]
# code 2-3: filter the variable "age" from matrix X

# %%
X["age"]
# Out:
# 0        58
# 1        44
# 2        33
# 3        47
# 4        33
#          ..
# 45206    51
# 45207    71
# 45208    72
# 45209    57
# 45210    37
# Name: age, Length: 45211, dtype: int64

# %% [markdown]
# code 2-4: filter the variables "age", "job","marital" and "education" from matrix X

# %%
X[["age", "education"]]
# Out:
#        age  education
# 0       58   tertiary
# 1       44  secondary
# 2       33  secondary
# 3       47        NaN
# 4       33        NaN
# ...    ...        ...
# 45206   51   tertiary
# 45207   71    primary
# 45208   72  secondary
# 45209   57  secondary
# 45210   37  secondary
#
# [45211 rows x 2 columns]

# %%
X[["age", "job","marital","education"]]
# Out:
#        age           job   marital  education
# 0       58    management   married   tertiary
# 1       44    technician    single  secondary
# 2       33  entrepreneur   married  secondary
# 3       47   blue-collar   married        NaN
# 4       33           NaN    single        NaN
# ...    ...           ...       ...        ...
# 45206   51    technician   married   tertiary
# 45207   71       retired  divorced    primary
# 45208   72       retired   married  secondary
# 45209   57   blue-collar   married  secondary
# 45210   37  entrepreneur   married  secondary
#
# [45211 rows x 4 columns]

# %%
pip install pandas openpyxl

# %%
import pandas as pd

df = pd.DataFrame(X)

df.to_excel('output.xlsx', index=False)

# %%
X[X["marital"] == "married"]
# Out:
#        age           job  marital  education default  balance housing loan  \
# 0       58    management  married   tertiary      no     2143     yes   no
# 2       33  entrepreneur  married  secondary      no        2     yes  yes
# 3       47   blue-collar  married        NaN      no     1506     yes   no
# 5       35    management  married   tertiary      no      231     yes   no
# 8       58       retired  married    primary      no      121     yes   no
# ...    ...           ...      ...        ...     ...      ...     ...  ...
# 45204   73       retired  married  secondary      no     2850      no   no
# 45206   51    technician  married   tertiary      no      825      no   no
# 45208   72       retired  married  secondary      no     5715      no   no
# 45209   57   blue-collar  married  secondary      no      668      no   no
# 45210   37  entrepreneur  married  secondary      no     2971      no   no
#
# ...

# %% [markdown]
# code 2-5: filter the variables "age", "job","marital" and "education" from matrix X and specifing only "married".

# %%
bank_DF=X[X["marital"] == "married"][["age", "job", "marital", "education","housing"]]
bank_DF
#X['marital'] == 'married' #check the function of code
# Out:
#        age           job  marital  education housing
# 0       58    management  married   tertiary     yes
# 2       33  entrepreneur  married  secondary     yes
# 3       47   blue-collar  married        NaN     yes
# 5       35    management  married   tertiary     yes
# 8       58       retired  married    primary     yes
# ...    ...           ...      ...        ...     ...
# 45204   73       retired  married  secondary      no
# 45206   51    technician  married   tertiary      no
# 45208   72       retired  married  secondary      no
# 45209   57   blue-collar  married  secondary      no
# 45210   37  entrepreneur  married  secondary      no
#
# [27214 rows x 5 columns]

# %% [markdown]
# code 2-6: filter the variables "age", "job","marital" and "education" from matrix X. Specifing only "married" and age=20.

# %%
X[(X["marital"] == "married") & (X["age"]==20)] [["age", "job", "marital", "education"]]
# Out:
#        age          job  marital education
# 4157    20  blue-collar  married   primary
# 34204   20      student  married       NaN
# 40647   20      student  married       NaN

# %% [markdown]
# code 2-6: filter the variables "age", "job","marital" and "education" from matrix X. Specifing only "married" and 18<=age<23.

# %%
testDF=X[(X["marital"] == "married") & (X["age"]>= 18) & (X["age"]< 23) ] [["age", "job", "marital", "education"]]
testDF
# Out:
#        age          job  marital  education
# 2345    22     services  married  secondary
# 3301    21     services  married  secondary
# 4157    20  blue-collar  married    primary
# 4258    22  blue-collar  married  secondary
# 4529    22     services  married  secondary
# 6248    21  blue-collar  married  secondary
# 6698    22  blue-collar  married  secondary
# 8406    21   unemployed  married  secondary
# 8748    22     services  married    primary
# 8800    21  blue-collar  married    primary
# 8818    22       admin.  married  secondary
# 12338   22  blue-collar  married  secondary
# 34204   20      student  married        NaN
# 35126   22  blue-collar  married  secondary
# 38155   21  blue-collar  married    primary
# 39288   22     services  married  secondary
# 40647   20      student  married        NaN

# %% [markdown]
# [***2point***]
#
# **Assignment01 make dataframe, variables are "age", "job", "marital", "education", and education is secondary or tertiary.**

# %%
import pandas as pd

# %%
education_counts = X['education'].value_counts()
education_counts
# Out:
# education
# secondary    23202
# tertiary     13301
# primary       6851
# Name: count, dtype: int64

# %%
testDF = X[(X["education"] == "tertiary") | (X["education"] == "secondary")][["age", "job", "marital", "education"]]
testDF
# Out:
#        age           job  marital  education
# 0       58    management  married   tertiary
# 1       44    technician   single  secondary
# 2       33  entrepreneur  married  secondary
# 5       35    management  married   tertiary
# 6       28    management   single   tertiary
# ...    ...           ...      ...        ...
# 45205   25    technician   single  secondary
# 45206   51    technician  married   tertiary
# 45208   72       retired  married  secondary
# 45209   57   blue-collar  married  secondary
# 45210   37  entrepreneur  married  secondary
#
# [36503 rows x 4 columns]

# %% [markdown]
# ###**Part3**###
# code 3-1: merge dataframes by using pd.merge.

# %%
import pandas as pd
df=pd.merge(y, X, right_index=True, left_index=True)
df
# Out:
#          y  age           job   marital  education default  balance housing  \
# 0       no   58    management   married   tertiary      no     2143     yes
# 1       no   44    technician    single  secondary      no       29     yes
# 2       no   33  entrepreneur   married  secondary      no        2     yes
# 3       no   47   blue-collar   married        NaN      no     1506     yes
# 4       no   33           NaN    single        NaN      no        1      no
# ...    ...  ...           ...       ...        ...     ...      ...     ...
# 45206  yes   51    technician   married   tertiary      no      825      no
# 45207  yes   71       retired  divorced    primary      no     1729      no
# 45208  yes   72       retired   married  secondary      no     5715      no
# 45209   no   57   blue-collar   married  secondary      no      668      no
# 45210   no   37  entrepreneur   married  secondary      no     2971      no
#
# ...

# %%
resultDF =df.assign(type='bank-additional-full')
resultDF
# Out:
#          y  age           job   marital  education default  balance housing  \
# 0       no   58    management   married   tertiary      no     2143     yes
# 1       no   44    technician    single  secondary      no       29     yes
# 2       no   33  entrepreneur   married  secondary      no        2     yes
# 3       no   47   blue-collar   married        NaN      no     1506     yes
# 4       no   33           NaN    single        NaN      no        1      no
# ...    ...  ...           ...       ...        ...     ...      ...     ...
# 45206  yes   51    technician   married   tertiary      no      825      no
# 45207  yes   71       retired  divorced    primary      no     1729      no
# 45208  yes   72       retired   married  secondary      no     5715      no
# 45209   no   57   blue-collar   married  secondary      no      668      no
# 45210   no   37  entrepreneur   married  secondary      no     2971      no
#
# ...

# %%
import numpy as np
# convert resultDF as dataframe df02
df02 = pd.DataFrame(resultDF)
# add variable "agegroup"
df02['agegroup'] = np.where(df02['age'] >= 50, '50歳以上',
                                        np.where(df02['age'] >= 30, '30歳以上49歳', '29歳以下'))
# convert resultDF
df02= pd.DataFrame(df02)
# show daraframe
df02
# Out:
#          y  age           job   marital  education default  balance housing  \
# 0       no   58    management   married   tertiary      no     2143     yes
# 1       no   44    technician    single  secondary      no       29     yes
# 2       no   33  entrepreneur   married  secondary      no        2     yes
# 3       no   47   blue-collar   married        NaN      no     1506     yes
# 4       no   33           NaN    single        NaN      no        1      no
# ...    ...  ...           ...       ...        ...     ...      ...     ...
# 45206  yes   51    technician   married   tertiary      no      825      no
# 45207  yes   71       retired  divorced    primary      no     1729      no
# 45208  yes   72       retired   married  secondary      no     5715      no
# 45209   no   57   blue-collar   married  secondary      no      668      no
# 45210   no   37  entrepreneur   married  secondary      no     2971      no
#
# ...

# %% [markdown]
# [***2point***]
#
# **Assignment02 add new variable "agegroup", age<40 as '40歳未満' and age>39 as '40歳以上', to dataframe df02.**

# %% [markdown]
# [***2point***]
#
# **Assignment03 add new variable "conversion", y="no" as '0' and y=1 as '1', to dataframe df02.**

# %% [markdown]
# not yet below

# %%
import numpy as np

# %% [markdown]
# code_09 ageの合計を計算

# %%
sum(X["age"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1ae67015c158> in <cell line: 1>()
# ----> 1 sum(X["age"])
#
# NameError: name 'X' is not defined

# %%
https://plotly.com/python/renderers/
https://colab.research.google.com/github/shibats/minpy_samplecodes_4th/blob/master/Chapter12/12-03.ipynb
https://colab.research.google.com/github/shibats/minpy_samplecodes_4th/blob/master/Chapter12/12-01.ipynb#scrollTo=7LKdq19ICSXe
https://note.com/k_fukunaka/n/nc418095a782e
